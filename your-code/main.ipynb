# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span></li><li><span><a href="#Challenge-1---Index-Functions" data-toc-modified-id="Challenge-1---Index-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Challenge 1 - Index Functions</a></span></li><li><span><a href="#Challenge-2---Advanced-Functions" data-toc-modified-id="Challenge-2---Advanced-Functions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Challenge 2 - Advanced Functions</a></span></li><li><span><a href="#Challenge-3---Method-Chaining" data-toc-modified-id="Challenge-3---Method-Chaining-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Challenge 3 - Method Chaining</a></span></li></ul></div>

# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
admissions.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions.set_index("Serial No.", inplace = True)
admissions.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
admissions["GRE Score"].unique()
# Out:
# array([337, 316, 322, 314, 330, 321, 308, 302, 323, 327, 328, 307, 311,
#        317, 319, 318, 303, 325, 334, 336, 298, 295, 310, 300, 338, 340,
#        331, 320, 299, 304, 313, 332, 326, 329, 339, 312, 324, 309, 315,
#        301, 296, 294, 306, 305, 290, 335, 333, 297, 293], dtype=int64)

# %%
admissions["CGPA"].unique()
# Out:
# array([9.65, 8.  , 8.67, 8.21, 9.34, 8.2 , 7.9 , 8.6 , 9.  , 9.1 , 8.3 ,
#        8.7 , 8.8 , 8.5 , 8.4 , 9.5 , 9.7 , 9.8 , 7.5 , 7.2 , 7.3 , 8.1 ,
#        9.4 , 9.6 , 9.2 , 7.8 , 7.7 , 9.3 , 8.85, 7.4 , 7.6 , 6.8 , 8.92,
#        9.02, 8.64, 9.22, 9.16, 9.64, 9.76, 9.45, 9.04, 8.9 , 8.56, 8.72,
#        8.22, 7.54, 7.36, 8.02, 9.36, 8.66, 8.42, 8.28, 8.14, 7.92, 7.66,
#        8.03, 7.88, 7.84, 8.96, 9.24, 8.88, 8.46, 8.12, 8.25, 8.47, 9.05,
#        8.78, 9.18, 9.46, 9.38, 8.48, 8.68, 8.34, 8.45, 8.62, 7.46, 7.28,
#        8.84, 9.56, 9.48, 8.36, 9.32, 8.71, 9.35, 8.65, 9.28, 8.77, 8.16,
#        9.08, 9.12, 9.15, 9.44, 9.92, 9.11, 8.26, 9.43, 9.06, 8.75, 8.89,
#        8.69, 7.86, 9.01, 8.97, 8.33, 8.27, 7.98, 8.04, 9.07, 9.13, 9.23,
#        8.87, 8.98, 8.94, 9.53, 8.76, 8.52, 8.54, 9.91, 9.87, 7.65, 7.89,
#        9.14, 9.66, 9.78, 9.42, 9.26, 8.23, 8.07, 9.31, 9.17, 9.19, 8.37,
#        7.68, 8.15, 8.73, 8.83, 8.57, 9.68, 8.09, 8.79, 8.17, 7.64, 8.01,
#        7.95, 8.49, 7.87, 7.97, 8.18, 8.32, 8.55, 8.43, 8.53, 8.74, 8.44,
#        9.47, 8.24, 8.13, 7.34, 7.43, 7.25, 8.06, 7.67, 9.54, 9.62, 7.56,
#        9.74, 9.82, 7.96])

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
admissions.set_index(["GRE Score","CGPA"], inplace = True)
admissions
# Out:
#                 TOEFL Score  University Rating  SOP  LOR  Research  \
# GRE Score CGPA
# 337       9.65          118                  4  4.5  4.5         1
# 316       8.00          104                  3  3.0  3.5         1
# 322       8.67          110                  3  3.5  2.5         1
# 314       8.21          103                  2  2.0  3.0         0
# 330       9.34          115                  5  4.5  3.0         1
# ...                     ...                ...  ...  ...       ...
# 324       9.04          110                  3  3.5  3.5         1
# 325       9.11          107                  3  3.0  3.5         1
# 330       9.45          116                  4  5.0  4.5         1
# 312       8.78          103                  3  3.5  4.0         0
# 333       9.66          117                  4  5.0  4.0         1
#
#                 Chance of Admit
# GRE Score CGPA
# 337       9.65             0.92
# 316       8.00             0.72
# 322       8.67             0.80
# 314       8.21             0.65
# 330       9.34             0.90
# ...                         ...
# 324       9.04             0.82
# 325       9.11             0.84
# 330       9.45             0.91
# 312       8.78             0.67
# 333       9.66             0.95
#
# [385 rows x 6 columns]

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
admissions.reset_index(inplace=True)

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:

print(len(admissions[(admissions.CGPA > 9) & (admissions.Research == 1)]))
admissions[(admissions.CGPA > 9) & (admissions.Research == 1)]
# Out:
# 101
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 4             5        330          115                  5  4.5  3.0  9.34
# 10           11        328          112                  4  4.0  4.5  9.10
# 19           20        328          116                  5  5.0  5.0  9.50
# 20           21        334          119                  5  5.0  4.5  9.70
# ..          ...        ...          ...                ...  ...  ...   ...
# 379         380        329          111                  4  4.5  4.0  9.23
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# 4           1             0.90
# 10          1             0.78
# 19          1             0.94
# 20          1             0.95
# ..        ...              ...
# 379         1             0.89
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 384         1             0.95
#
# [101 rows x 9 columns]

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:
chance_mean=admissions[(admissions.CGPA > 9) & (admissions.SOP < 3.5)]
print(f'the chance mean of this conditional is {chance_mean["Chance of Admit"].mean()}')
chance_mean
# Out:
# the chance mean of this conditional is 0.8019999999999999
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 28           29        338          118                  4  3.0  4.5  9.40
# 62           63        327          114                  3  3.0  3.0  9.02
# 140         141        326          114                  3  3.0  3.0  9.11
# 217         218        324          111                  4  3.0  3.0  9.01
# 381         382        325          107                  3  3.0  3.5  9.11
#
#      Research  Chance of Admit
# 28          1             0.91
# 62          0             0.61
# 140         1             0.83
# 217         1             0.82
# 381         1             0.84

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    
    # Your code here:
    
    return (col - col.mean()) / col.std()

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions["CGPA_std"]=standardize(admissions.CGPA)
admissions["GRE_std"]=standardize(admissions["GRE Score"])
admissions["LOR_std"]=standardize(admissions.LOR)
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0         1             0.92  1.747900  1.753381  1.191647
# 1         1             0.72 -0.991211 -0.063367  0.076740
# 2         1             0.80  0.121034  0.455704 -1.038166
# 3         0             0.65 -0.642597 -0.236391 -0.480713
# 4         1             0.90  1.233279  1.147798 -0.480713

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std','GRE_std','LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])
#pd.DataFrame(np.random.normal(15,6,(10,4)), columns=['winter','spring','summer','autumn'])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
admissions.lookup([decision_choice],['deciding_column'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-51bfc8e550fa> in <module>
# ----> 1 admissions.lookup([decision_choice],['deciding_column'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in lookup(self, row_labels, col_labels)
#    3720             result = np.empty(n, dtype="O")
#    3721             for i, (r, c) in enumerate(zip(row_labels, col_labels)):
# -> 3722                 result[i] = self._get_value(r, c)
#    3723
#    3724         if is_object_dtype(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    2917         # use positional
#    2918         col = self.columns.get_loc(col)
# -> 2919         index = self.index.get_loc(index)
#    2920         return self._get_value(index, col, takeable=True)
#    2921
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     351             except ValueError:
#     352                 raise KeyError(key)
# --> 353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#     355     @Appender(_index_shared_docs["get_indexer"])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'LOR_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'LOR_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std' ...

# %%
decision_choice= decision_choice

admissions["deciding_column"]= decision_choice
admissions["deciding_column"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-077330720152> in <module>
#       1 decision_choice= decision_choice
#       2
# ----> 3 admissions["deciding_column"]= decision_choice
#       4 admissions["deciding_column"]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
for i in admissions["deciding_column"]:
    print(i)
# Out:
# CGPA_std
# GRE_std
# GRE_std
# LOR_std
# GRE_std
# LOR_std
# CGPA_std
# GRE_std
# LOR_std
# LOR_std
# CGPA_std
# LOR_std
# LOR_std
# CGPA_std
# GRE_std
# LOR_std
# GRE_std
# CGPA_std
# LOR_std
# LOR_std
# GRE_std
# CGPA_std
# GRE_std
# CGPA_std
# LOR_std
# GRE_std
# GRE_std
# CGPA_std
# GRE_std
# LOR_std
# GRE_std
# LOR_std
# CGPA_std
# CGPA_std
# GRE_std
# LOR_std
# GRE_std
# LOR_std
# LOR_std
# LOR_std
# GRE_std
# GRE_std
# CGPA_std
# CGPA_std
# CGPA_std
# GRE_std
# LOR_std
# LOR_std
# LOR_std
# GRE_std
# LOR_std
# GRE_std
# GRE_std
# CGPA_std
# LOR_std
# CGPA_std
# LOR_std
# LOR_std
# LOR_std
# GRE_std
# LOR_std
# GRE_std
# CGPA_std
# GRE_std
# GRE_std
# LOR_std
# LOR_std
# GRE_std
# GRE_std
# GRE_std
# CGPA_std
# CGPA_std
# CGPA_std
# GRE_std
# CGPA_std
# LOR_std
# LOR_std
# GRE_std
# LOR_std
# GRE_std
# GRE_std
# LOR_std
# CGPA_std
# LOR_std
# GRE_std
# LOR_std
# GRE_std
# GRE_std
# LOR_std
# CGPA_std
# CGPA_std
# GRE_std
# GRE_std
# GRE_std
# LOR_std
# CGPA_std
# LOR_std
# GRE_std
# GRE_std
# GRE_std
# LOR_std
# CGPA_std
# CGPA_std
# GRE_std
# CGPA_std
# GRE_std
# CGPA_std
# CGPA_std
# CGPA_std
# GRE_std
# LOR_std
# CGPA_std
# GRE_std
# LOR_std
# CGPA_std
# CGPA_std
# CGPA_std
# GRE_std
# LOR_std
# CGPA_std
# GRE_std
# LOR_std
# GRE_std
# GRE_std
# LOR_std
# GRE_std
# GRE_std
# LOR_std
# CGPA_std
# LOR_std
# LOR_std
# CGPA_std
# GRE_std
# LOR_std
# CGPA_std
# GRE_std
# CGPA_std
# LOR_std
# GRE_std
# LOR_std
# GRE_std
# LOR_std
# LOR_std
# CGPA_std
# LOR_std
# CGPA_std
# GRE_std
# CGPA_std
# GRE_std
# GRE_std
# GRE_std
# GRE_std
# LOR_std
# GRE_std
# LOR_std
# CGPA_std
# GRE_std
# GRE_std
# GRE_std
# GRE_std
# CGPA_std
# LOR_std
# LOR_std
# CGPA_std
# LOR_std
# CGPA_std
# GRE_std
# CGPA_std
# CGPA_std
# LOR_std
# LOR_std
# CGPA_std
# LOR_std
# LOR_std
# GRE_std
# CGPA_std
# CGPA_std
# LOR_std
# GRE_std
# GRE_std
# CGPA_std

# %%
# Your code here:
admissions.loc[(admissions["deciding_column"] > 0.8), admissions["decision"]]

admissions.loc[(admissions["deciding_column"] >= 0), admissions["decision"]]

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
admissions.columns=admissions.columns.str.replace(".","").str.replace(" ","_").str.upper()

# %%
# Your code here:
admissions.head(2)
# Out:
#    SERIAL_NO  GRE_SCORE  TOEFL_SCORE  UNIVERSITY_RATING  SOP  LOR  CGPA  \
# 0          1        337          118                  4  4.5  4.5  9.65
# 1          2        316          104                  3  3.0  3.5  8.00
#
#    RESEARCH  CHANCE_OF_ADMIT  CGPA_STD   GRE_STD   LOR_STD  \
# 0         1             0.92  1.747900  1.753381  1.191647
# 1         1             0.72 -0.991211 -0.063367  0.076740
#
#                                      DECIDING_COLUMN
# 0  0      1.191647
# 1      0.076740
# 2     -1.03816...
# 1  0      1.747900
# 1     -0.991211
# 2      0.12103...

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:
admissions[(admissions["UNIVERSITY_RATING"] >= 4) & (admissions["GRE_SCORE"] ]
# Out:
#      SERIAL_NO  GRE_SCORE  TOEFL_SCORE  UNIVERSITY_RATING  SOP  LOR  CGPA  \
# 4            5        330          115                  5  4.5  3.0  9.34
# 19          20        328          116                  5  5.0  5.0  9.50
# 20          21        334          119                  5  5.0  4.5  9.70
# 21          22        336          119                  5  4.0  3.5  9.80
# 22          23        322          109                  5  4.5  3.5  8.80
# 29          30        340          114                  5  4.0  4.0  9.60
# 30          31        331          112                  5  4.0  5.0  9.80
# 31          32        320          110                  5  5.0  5.0  9.20
# 40          41        326          113                  5  4.5  4.0  9.40
# 41          42        322          110                  5  5.0  4.0  9.10
# 42          43        329          114                  5  4.0  5.0  9.30
# 43          44        339          119                  5  4.5  4.0  9.70
# 66          67        332          118                  5  5.0  5.0  9.64
# 67          68        336          112                  5  5.0  5.0  9.76
# 68          69        321          111                  5  5.0  5.0  9.45
# 78          79        320          110                  5  5.0  4.5  9.22
# 79          80        322          115                  5  4.0  4.5  9.36
# 80          81        340          115                  5  4.5  4.5  9.45
# 103        104        331          116                  5  5.0  5.0  9.38
# 104        105        304          103                  5  5.0  4.0  8.64
# 105        106        305          108                  5  3.0  3.0  8.48
# 114        115        327          104                  5  3.0  3.5  8.84
# 115        116        335          117                  5  5.0  5.0  9.56
# 116        117        334          119                  5  4.5  4.5  9.48
# 124        125        333          118                  5  5.0  5.0  9.35
# 125        126        339          114                  5  4.0  4.5  9.76
# 126        127        303          105                  5  5.0  4.5  8.65
# 127        128        323          112                  5  4.0  4.5  8.78
# 128        129        333          113                  5  4.0  4.0  9.28
# 135        136        331          115                  5  4.0  3.5  9.44
# 144        145        332          116                  5  5.0  5.0  9.28
# 145        146        321          112                  5  5.0  5.0  9.06
# 158        159        322          110                  5  4.5  4.0  8.97
# 164        165        334          117                  5  4.0  4.5  9.07
# 179        180        335          118                  5  4.5  3.5  9.44
# 180        181        331          115                  5  4.5  3.5  9.36
# 181        182        324          111                  5  4.5  4.0  9.16
# 182        183        323          110                  5  4.0  5.0  8.98
# 183        184        322          114                  5  4.5  4.0  8.94
# 184        185        336          118                  5  4.5  5.0  9.53
# 192        193        340          120                  5  4.5  4.5  9.91
# 193        194        334          120                  5  4.0  5.0  9.87
# 203        204        333          119                  5  5.0  4.5  9.78
# 205        206        330          116                  5  5.0  4.5  9.36
# 222        223        330          113                  5  5.0  4.0  9.31
# 223        224        326          111                  5  4.5  4.0  9.23
# 225        226        329          114                  5  4.5  5.0  9.19
# 247        248        327          108                  5  5.0  3.5  9.13
# 263        264        329          113                  5  5.0  4.5  9.45
# 272        273        331          116                  5  4.0  4.0  9.26
# 273        274        336          118                  5  4.5  4.0  9.19
# 274        275        324          114                  5  5.0  4.5  9.08
# 322        323        332          118                  5  5.0  5.0  9.47
# 323        324        323          108                  5  4.0  4.0  8.74
